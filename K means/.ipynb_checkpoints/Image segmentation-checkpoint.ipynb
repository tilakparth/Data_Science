# %%
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
img = cv2.imread("../me.jpg")
img = cv2.cvtColor(img,2)
original_shape = img.shape

# %%
plt.style.use("seaborn")
plt.grid(False)
plt.imshow(img)

# %%
print(img.shape)
# Out:
# (2065, 2105, 4)

# %%
all_pixels = img.reshape((-1,4))

# %%
all_pixels.shape
# Out:
# (4346825, 4)

# %%
from sklearn.cluster import KMeans

# %%
dominant_colors = 10
km = KMeans(n_clusters=dominant_colors)
km.fit(all_pixels)
# Out:
# KMeans(n_clusters=10)

# %%
centers = km.cluster_centers_

# %%
pred = km.labels_

# %%
centers = np.array(centers,dtype = "uint8")

# %%
i = 1
plt.figure(0,figsize=(20,10))
colors = []

for each_col in centers:
    plt.subplot(1,dominant_colors,i)
    plt.axis("off")
    i+=1
    colors.append(each_col)
    a = np.zeros((100,100,4),dtype = "uint8")
    a[:,:,:] =each_col
    plt.imshow(a)

# %% [markdown]
# ### Segmenting our original image

# %%
new_img = np.zeros(all_pixels.shape,dtype="uint8")

# %%
pred
# Out:
# array([7, 7, 7, ..., 8, 8, 8])

# %%
colors
# Out:
# [array([254, 165,  39, 255], dtype=uint8),
#  array([138, 133, 128, 255], dtype=uint8),
#  array([226, 231, 227, 255], dtype=uint8),
#  array([172, 113,  93, 255], dtype=uint8),
#  array([241, 114,  51, 255], dtype=uint8),
#  array([107,  67,  58, 255], dtype=uint8),
#  array([253, 178,  84, 255], dtype=uint8),
#  array([166, 158, 150, 255], dtype=uint8),
#  array([207, 208, 205, 255], dtype=uint8),
#  array([117, 102,  98, 255], dtype=uint8)]

# %%
for ix in range(new_img.shape[0]):
    new_img[ix] = colors[pred[ix]]

# %%
new_img = new_img.reshape(original_shape)

# %%
plt.imshow(new_img)
plt.grid(False)
