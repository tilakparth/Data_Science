# %%
import pandas as pd

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
type(tips)
# Out:
# pandas.core.frame.DataFrame

# %%
sns.barplot(x ="sex", y="total_bill" ,data= tips ,estimator=np.std)

# %%
sns.countplot(x="sex",data=tips)

# %%
sns.countplot(x="time",data= tips)

# %%
sns.boxplot(x="day",y='total_bill',data=tips,hue ="sex")

# %%
sns.violinplot(x= "day",y="total_bill",data =tips,hue="smoker",split=True)

# %%
sns.distplot(tips["total_bill"])

# %%
sns.jointplot(x="total_bill",y="tip",data= tips)

# %%
sns.jointplot?

# %%
sns.pairplot(tips,hue="sex",palette=["red","yellow"])

# %%
sns.pairplot?

# %%
tips_corr  =tips.corr()

# %%
sns.heatmap(tips_corr,annot=True)

# %% [markdown]
# # New data set

# %%
flights = sns.load_dataset('flights')

# %%
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
flights.corr()
# Out:
#                 year  passengers
# year        1.000000    0.921824
# passengers  0.921824    1.000000

# %%
flights_pivot  =flights.pivot_table(index="month",columns="year",values = "passengers")

# %%
flights_pivot
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.heatmap(flights_pivot)

# %% [markdown]
# # titanic

# %%
titanic = sns.load_dataset("titanic")

# %%
# titanic

# %%
titanic = titanic.drop(["who","alive","embarked","class","deck"],1)

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'adult_male', 'embark_town', 'alone'],
#       dtype='object')

# %%
titanic_piovt = titanic.pivot_table(index ="pclass",columns="sex",values="survived")

# %%
print(titanic_piovt)
sns.heatmap(titanic_piovt)
# Out:
# sex       female      male
# pclass
# 1       0.968085  0.368852
# 2       0.921053  0.157407
# 3       0.500000  0.135447

# %%
sns.catplot(x="sex",hue="survived",data = titanic,palette="Set1",col="pclass",kind = "count")

# %%
sns.violinplot(x= "sex",y="age",data = titanic,hue="survived",split=True)

# %%
sns.catplot?
